# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav251999/Projects/blob/main/rough_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def binarysearch(array,x,low,high):
  while low<=high:
      mid=low+(high-low)//2
  if array[mid]==x:
    return mid
  elif array[mid]<x:
    low=mid+1
  else:
    high=mid-1
  return -1
array=[3,1,7,8,5,2]
x=2
result=binarysearch(array,x,0,len(array)-1)
if result!=1:
  print("elemrnt in present at index:"+str(result))
else:
    print("Not found")

# %%
sentence= 'this is good day and this is a good sign '
word=[]
count=[]
l=list(sentence.split())
for w in l:
  if w not in word:
      word.append(w)
      count.append(l.count(w))
for i in range(len(word)):
  print('word  ',word[i],' occour ',count[i],' times')

# %%
# Out:
# word   this  occour  2  times
# word   is  occour  2  times
# word   good  occour  2  times
# word   day  occour  1  times
# word   and  occour  1  times
# word   a  occour  1  times
# word   sign  occour  1  times

# %%
s=0
def series(n):
  if n==1:
    return 1
  else:
    return (1/n+series(n-1))

# %%
series(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-adef9983c353> in <module>()
# ----> 1 series(4)
#
# NameError: name 'series' is not defined

# %%
# Python program for implementation of MergeSort
def mergeSort(arr):
	if len(arr) > 1:

		# Finding the mid of the array
		mid = len(arr)//2

		# Dividing the array elements
		L = arr[:mid]

		# into 2 halves
		R = arr[mid:]

		# Sorting the first half
		mergeSort(L)

		# Sorting the second half
		mergeSort(R)

		i = j = k = 0

		# Copy data to temp arrays L[] and R[]
		while i < len(L) and j < len(R):
			if L[i] < R[j]:
				arr[k] = L[i]
				i += 1
			else:
				arr[k] = R[j]
				j += 1
			k += 1

		# Checking if any element was left
		while i < len(L):
			arr[k] = L[i]
			i += 1
			k += 1

		while j < len(R):
			arr[k] = R[j]
			j += 1
			k += 1
array=[2,1,4,2,5,6,8,4]
mergeSort(array)
print(array)
# Out:
# [1, 2, 2, 4, 4, 5, 6, 8]

# %%
l=[3,9,2,1,4]
n=2
count=0
flag=0
for i in range(len(l)):
  if l[i]==n:
    count+=1
    flag=1
    print('found at postion',i,' in ',count,' step')
  count+=1
if flag==0:
  print('Not found')
# Out:
# found at postion 2  in  3  step

# %%
s=' '
n=3
for i in range(1,n+1):
  s1=[]
  for j in range(n-(i-1),n+1):
    s1.append(j)
  print(s*(n-i),*s1,sep='')
# Out:
#   3
#  23
# 123

# %%
s=' '
n=3
for i in range(n,0,-1):
  s1=[]
  for j in range(i,n+1):
    s1.append(j)
  print(s*i,*s1,sep='')
# Out:
#    3
#   23
#  123

# %%
for i in range(4,1,-1):
  print(i)
# Out:
# 4
# 3
# 2

# %%
a='bablu ji'

#d=a+10 # TypeError
s=[1,2,3,4,5,6,7,9]
d='i am bablu ji'   # i space a m space b a b j i
#for elem in s:   # element wala for loop 
  #print(elem**2)
# range wala for loop
#for i in range(1,10,2):  # range(1,5) = 1,2,3,4
  #print(i*i)
print('bablu','\nvaibhav')
# Out:
# bablu
# vaibhav

# %%
d=[1,3,5,7]   # 0,1,2,3,4
s='vaibhav'  # the way we define is string so , doesnt matter hat is written inside the columns
# indexing 
#print(d[1]==3)
#print(s[3]=='b')
#print(d[-3]) # -1 used for last element
#print(s[-1]) # negetive indexing 
 # why giving false ???
#print(1==1)  # when compared in python it return boolean (true/false)
# slicing
#print(s[start:stop]) # start , start+1 .....stop -1
#print(s[3:-4])
print(s[:]) # complete value 
print(s[0:]) # cimplete value
print(s[0:-1]) # upto last-1 value
print(s[:-1]) # upto last-1 value
print(d[::-1]) # reverse a string
# mutability # property of any data type to change its value # like mutation in covid virus
d[0]=10 # value change is called mutability 
d[2]=17 # list is mutable
# s[0]='b' #TypeError: 'str' object does not support item assignment
print(d)
# Out:
# vaibhav
# vaibhav
# vaibha
# vaibha
# [7, 5, 3, 1]
# [10, 3, 17, 7]

# %%
"Hello world"
# Out:
# 'Hello world'

# %%
A=("My name is Bablu")
print(A)
print("World is so sweet".lower())
print("World is so sweet".upper())
print("World is so sweet".count("e"))
print("World is so sweet".replace("o","a"))
# Out:
# My name is Bablu
# world is so sweet
# WORLD IS SO SWEET
# 2
# Warld is sa sweet

# %% [markdown]
# Slicing the terms

# %%
A=[3,2,8,6,9,6,5,7,8,10]
print(A)

max(A)
min(A)
print(A.count(7))
print(A[1:8])
print(A.upper())
# Out:
# [3, 2, 8, 6, 9, 6, 5, 7, 8, 10]
# 1
# [2, 8, 6, 9, 6, 5, 7]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-14fa6da9a127> in <module>()
#       6 print(A.count(7))
#       7 print(A[1:8])
# ----> 8 print(A.upper())
#
# AttributeError: 'list' object has no attribute 'upper'

# %% [markdown]
# Practice 16/04/22

# %%
print("My name is Bablu Kumar Sharma.",end='3')
print("I am 27 years old.")
# Out:
# My name is Bablu Kumar Sharma.3I am 27 years old.

# %%
l=int("5")
b=int("3")
Ar=l*b
print(Ar)
# Out:
# 15

# %%
#To find the area of triangle
Ht=23
Bs=10
Ar=(Ht*Bs)/2
print(Ar)
# Out:
# 115.0

# %%
 #Pythagorus theoram

H=float("5")
B=float("4")
P=(H**2-B**2)**(.5)
print(P)
# Out:
# 3.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from scipy import misc

def read_image():
	img = misc.imread('bird_small.png')
	img = img / 255

	return img

def initialize_means(img, clusters):
	
	# reshaping it or flattening it into a 2d matrix
	points = np.reshape(img, (img.shape[0] * img.shape[1],
											img.shape[2]))
	m, n = points.shape

	# clusters is the number of clusters
	# or the number of colors that we choose.
	
	# means is the array of assumed means or centroids.
	means = np.zeros((clusters, n))

	# random initialization of means.
	for i in range(clusters):
		rand1 = int(np.random.random(1)*10)
		rand2 = int(np.random.random(1)*8)
		means[i, 0] = points[rand1, 0]
		means[i, 1] = points[rand2, 1]

	return points, means


# Function to measure the euclidean
# distance (distance formula)
def distance(x1, y1, x2, y2):

	return np.sqrt(np.square(x1 - x2) + np.square(y1 - y2))


def k_means(points, means, clusters):

	iterations = 10 # the number of iterations
	m, n = points.shape
	
	# these are the index values that
	# correspond to the cluster to
	# which each pixel belongs to.
	index = np.zeros(m)

	# k-means algorithm.
	while(iterations > 0):

		for j in range(len(points)):
			
			minv = 1000
			temp = None
			
			for k in range(clusters):
				
				x1 = points[j, 0]
				y1 = points[j, 1]
				x2 = means[k, 0]
				y2 = means[k, 1]
				
				if(distance(x1, y1, x2, y2) < minv):		
					minv = distance(x1, y1, x2, y2)
					temp = k
					index[j] = k
		
		for k in range(clusters):
			
			sumx = 0
			sumy = 0
			count = 0
			
			for j in range(len(points)):
				
				if(index[j] == k):
					sumx += points[j, 0]
					sumy += points[j, 1]
					count += 1
			
			if(count == 0):
				count = 1	
			
			means[k, 0] = float(sumx / count)
			means[k, 1] = float(sumy / count)	
			
		iterations -= 1

	return means, index


def compress_image(means, index, img):

	# recovering the compressed image by
	# assigning each pixel to its corresponding centroid.
	centroid = np.array(means)
	recovered = centroid[index.astype(int), :]
	
	# getting back the 3d matrix (row, col, rgb(3))
	recovered = np.reshape(recovered, (img.shape[0], img.shape[1],
													img.shape[2]))

	# plotting the compressed image.
	plt.imshow(recovered)
	plt.show()

	# saving the compressed image.
	misc.imsave('compressed_' + str(clusters) +
						'_colors.png', recovered)



img = read_image()

clusters = 16
clusters = int(input('Enter the number of colors in the compressed image. default = 16\n'))

points, means = initialize_means(img, clusters)
means, index = k_means(points, means, clusters)
compress_image(means, index, img)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as image
# %matplotlib inline
plt.style.use("ggplot")
from skimage import io
from sklearn.cluster import KMeans

plt.rcParams['figure.figsize'] = (10, 15)
img = io.imread('bird_small.jpg' )
labels = plt.axes(xticks=[], yticks=[])
labels.imshow(img);

# %%
img.shape
# Out:
# (830, 1200, 3)

# %%
image_data = (img / 255.0).reshape(img.shape[0] * img.shape[1], img.shape[2])
image_data.shape
# Out:
# (996000, 3)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=64)
kmeans.fit(image_data)
compressed_image = kmeans.cluster_centers_[kmeans.labels_]
compressed_image = np.clip(compressed_image.astype('uint8'), 0, 255)
compressed_image = compressed_image.reshape(img.shape[0], img.shape[1],img.shape[2])

# %%
io.imsave('compressed_image_64.png', compressed_image)
io.imshow(compressed_image)
io.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: compressed_image_64.png is a low contrast image
#   """Entry point for launching an IPython kernel.

# %%
io.imshow(k_colors)
